# %%
# Importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading the csv file into a dataframe
df = pd.read_csv('group_data_cleaning.csv', encoding='latin-1')

# %%
df.head()
# Out:
#   What is your gender  Year of graduation  \
# 0              Female                2013
# 1              Female                2013
# 2                Male                2015
# 3                Male                2013
# 4                Male                2015
#
#                Title of course studied       Polytechnic/University attended  \
# 0                            Economics  Bells University of Technology, Otta
# 1                           Statistics                Ekiti State University
# 2  Electrical & Electronic Engineering                   University of Benin
# 3                            Economics                 Bowen University, Iwo
# 4                          Accountancy    Obafemi Awolowo University,Ile-Ife
#
#   What is your highest level of education?  \
# 0                        Bachelor's degree
# 1                        Bachelor's degree
# 2                        Bachelor's degree
# 3            Higher National Diploma (HND)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2961 entries, 0 to 2960
# Data columns (total 35 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   What is your gender                                                                                                           2961 non-null   object
#  1   Year of graduation                                                                                                            2961 non-null   int64
#  2   Title of course studied                                                                                                       2961 non-null   object
# ...

# %%
# Change the column from float to int64
df['If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?'] = df['If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?'].astype('Int64')

# %%
# Fill NaN values with a default value (e.g., 0)
df['If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?'] = df['If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?'].fillna(0).astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2961 entries, 0 to 2960
# Data columns (total 35 columns):
#  #   Column                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                        --------------  -----
#  0   What is your gender                                                                                                           2961 non-null   object
#  1   Year of graduation                                                                                                            2961 non-null   int64
#  2   Title of course studied                                                                                                       2961 non-null   object
# ...

# %%
# Define a custom color palette
custom_palette = ["#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#8e44ad", "#e67e22"]

sns.set(style="whitegrid")

# Create a bar plot for "What is your gender" with the custom palette
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="What is your gender", palette=custom_palette)

# Add labels and title
plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Distribution of Gender")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
sns.set(style="whitegrid")

# Create a bar plot for "How many jobs have you had since graduation"
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="How many jobs have you had since graduation including your current one?", palette="viridis")

# Add labels and title
plt.xlabel("Number of Jobs")
plt.ylabel("Count")
plt.title("Number of Jobs Since Graduation")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
# Define a custom color palette
custom_palette = ["#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#8e44ad", "#e67e22"]

sns.set(style="whitegrid")

# Create a bar plot for "Approximately how many hours a day do you currently work?" with custom palette
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Approximately how many hours a day do you currently work?", palette=custom_palette)

# Add labels and title
plt.xlabel("Hours per Day")
plt.ylabel("Count")
plt.title("Daily Working Hours")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
sns.set(style="whitegrid")

# Create a box plot for "Approximately how many hours a day do you currently work?"
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, y="Approximately how many hours a day do you currently work?", palette="viridis")

# Add labels and title
plt.xlabel("Daily Working Hours")
plt.ylabel("Hours per Day")
plt.title("Box Plot of Daily Working Hours")

# Show the plot
plt.show()

# %%
# Define a custom color palette
custom_palette = ["#3498db", "#e74c3c", "#2ecc71", "#f1c40f", "#8e44ad"]

sns.set(style="whitegrid")

# Create a bar plot for "What is your highest level of education?" with the custom palette
plt.figure(figsize=(10, 6))
education_order = df["What is your highest level of education?"].value_counts().index
sns.countplot(data=df, y="What is your highest level of education?", order=education_order, palette=custom_palette)

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Highest Level of Education")
plt.title("Distribution of Highest Level of Education")

# Show the plot
plt.show()

# %%
# Define a custom color palette
custom_palette = ["#3498db", "#e74c3c", "#2ecc71"]

sns.set(style="whitegrid")

# Create a bar plot for "Have you completed your NYSC?" with the custom palette
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Have you completed your NYSC?", palette=custom_palette)

# Add labels and title
plt.xlabel("Completion Status")
plt.ylabel("Count")
plt.title("NYSC Completion Status")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a histogram for "Year of graduation"
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Year of graduation", bins=30, kde=True, color="#3498db")

# Add labels and title
plt.xlabel("Year of Graduation")
plt.ylabel("Count")
plt.title("Distribution of Year of Graduation")

# Show the plot
plt.show()

# %%
# Convert the "Year of graduation" column to int64
df['Year of graduation'] = df['Year of graduation'].astype('int64')

# Set the style for the plot
sns.set(style="whitegrid")

# Create a histogram for "Year of graduation"
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Year of graduation", bins=30, kde=True, color="#3498db")

# Add labels and title
plt.xlabel("Year of Graduation")
plt.ylabel("Count")
plt.title("Distribution of Year of Graduation")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a histogram for "Approximately how many hours a day do you currently work?"
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Approximately how many hours a day do you currently work?", bins=30, kde=True, color="#3498db")

# Add labels and title
plt.xlabel("Hours Worked per Day")
plt.ylabel("Count")
plt.title("Distribution of Daily Working Hours")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a histogram for "How many jobs have you had since graduation including your current one?"
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="How many jobs have you had since graduation including your current one?", bins=30, kde=True, color="#3498db")

# Add labels and title
plt.xlabel("Number of Jobs Since Graduation")
plt.ylabel("Count")
plt.title("Distribution of Jobs Since Graduation")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for "Did you get your first full-time job through your NYSC placement?"
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Did you get your first full time job through your NYSC placement?", palette="Set2")

# Add labels and title
plt.xlabel("NYSC Placement Status")
plt.ylabel("Count")
plt.title("First Full-Time Job through NYSC Placement")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a cross-tabulation table for "What is your gender" and "Did you get your first full-time job through your NYSC placement?"
cross_tab = pd.crosstab(index=df["What is your gender"], columns=df["Did you get your first full time job through your NYSC placement?"])

# Create a countplot based on the cross-tabulation table
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Did you get your first full time job through your NYSC placement?", hue="What is your gender", palette="Set2")

# Add labels and title
plt.xlabel("NYSC Placement Status")
plt.ylabel("Count")
plt.title("Gender-Based Differences in NYSC Placements")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for "What currency are you currently paid in?"
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y="What currency are you currently paid in?", palette="viridis")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Currency")
plt.title("Currency of Current Payment")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for "What best describes your current status?" with "What is your gender" as the legend
plt.figure(figsize=(10, 6))
plot = sns.countplot(data=df, x="What best describes your current status?", hue="What is your gender", palette="Set1")

# Add labels and title
plt.xlabel("Current Status")
plt.ylabel("Count")
plt.title("Current Status by Gender")

# Show the legend
plt.legend(title="Gender", loc="upper right")

# Rotate x-axis labels for better readability
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, horizontalalignment='right')

# Show the plot
plt.show()

# %%
# Group the data by "My course of study prepared me well for employment"
grouped_data = df["My course of study prepared me well for employment"].value_counts()

# Create a donut chart
fig, ax = plt.subplots()
ax.axis('equal')

# Plot the donut chart
colors = plt.cm.Set3(range(len(grouped_data)))
wedges, texts, autotexts = ax.pie(
    grouped_data,
    labels=grouped_data.index,
    autopct='%1.1f%%',
    pctdistance=0.85,
    colors=colors,
)

# Draw a circle in the center to create the donut effect
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# Set the title
plt.title("Course Preparedness for Employment")

# Show the plot
plt.show()

# %%
# Group the data by "My course of study prepared me well for further studies"
grouped_data = df["My course of study prepared me well for further studies"].value_counts()

# Define colors for the donut chart
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

# Create a donut chart
fig, ax = plt.subplots()
ax.axis('equal')

# Plot the donut chart with excellent colors
wedges, texts, autotexts = ax.pie(
    grouped_data,
    labels=grouped_data.index,
    autopct='%1.1f%%',
    pctdistance=0.85,
    colors=colors,
)

# Draw a circle in the center to create the donut effect
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig.gca().add_artist(centre_circle)

# Set the title
plt.title("Course Preparedness for Further Studies")

# Show the plot
plt.show()

# %%
correlation_matrix = df.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4888\1255290103.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define a function to generate and display word clouds
def generate_wordcloud(column_name, title):
    # Combine all text from the specified column into a single string
    text = " ".join(df[column_name].dropna())

    # Generate the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='black', colormap='viridis').generate(text)

    # Display the word cloud
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title(title)
    plt.show()

# Create word clouds for the specified columns
generate_wordcloud("Which of these skills/knowledge did your higher education prepare you for?", "Skills/Knowledge Prepared by Higher Education")
generate_wordcloud("As far as you are aware, what was most important to your current employer about your qualification?", "Importance to Current Employer")
generate_wordcloud("What was the most significant reason for deciding to take this job?", "Reason for Taking the Job")
generate_wordcloud("Reason why?", "Additional Reasons for Career Choices")

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 titles of courses studied
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Title of course studied", palette="viridis")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Title of Course Studied")
plt.title("Top 20 Titles of Courses Studied")

# Show the plot
plt.show()

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Get the titles with counts in descending order
title_counts = filtered_df['Title of course studied'].value_counts().reindex(top_20_titles)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 titles of courses studied with titles ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Title of course studied", palette="viridis",
                   order=title_counts.index)  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Title of Course Studied")
plt.title("Top 20 Titles of Courses Studied (Ranked)")

# Show the plot
plt.show()

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Get the titles with counts in descending order
title_counts = filtered_df['Title of course studied'].value_counts().reindex(top_20_titles)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 titles of courses studied with titles ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Title of course studied", palette="viridis",
                   order=title_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Title of Course Studied")
plt.title("Top 20 Titles of Courses Studied (Ranked) with Gender Legend")

# Show the plot
plt.legend(title="Gender")  
plt.show()

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Create a pivot table to count the number of each gender within each title
pivot_df = filtered_df.pivot_table(index='Title of course studied', columns='What is your gender', aggfunc='size', fill_value=0)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a stacked bar chart
plt.figure(figsize=(12, 8))
ax = pivot_df.plot(kind="bar", stacked=True, colormap="viridis")

# Add labels and title
plt.xlabel("Title of Course Studied")
plt.ylabel("Count")
plt.title("Stacked Bar Chart of Top 20 Titles of Courses Studied by Gender")

# Show the plot
plt.legend(title="Gender", loc='upper right')  
plt.show()

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Create a pivot table to count the number of each gender within each title
pivot_df = filtered_df.pivot_table(index='Title of course studied', columns='What is your gender', aggfunc='size', fill_value=0)

# Rank the titles by total count in descending order
ranked_titles = pivot_df.sum(axis=1).sort_values(ascending=False).index
pivot_df = pivot_df.loc[ranked_titles]

# Set the style for the plot
sns.set(style="whitegrid")

# Create a stacked bar chart
plt.figure(figsize=(12, 8))
ax = pivot_df.plot(kind="bar", stacked=True, colormap="viridis")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Title of Course Studied")
plt.title("Top 20 Titles of Courses Studied by Gender (Ranked)")

# Show the plot
plt.legend(title="Gender", loc='upper right') 
plt.show()

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Create a pivot table to count the number of each gender within each title
pivot_df = filtered_df.pivot_table(index='Title of course studied', columns='What is your gender', aggfunc='size', fill_value=0)

# Rank the titles by total count in descending order
ranked_titles = pivot_df.sum(axis=1).sort_values(ascending=False).index
pivot_df = pivot_df.loc[ranked_titles]

# Set the style for the plot
sns.set(style="whitegrid")

# Create a stacked bar chart
plt.figure(figsize=(12, 8))
ax = pivot_df.plot(kind="bar", stacked=True, colormap="viridis")

# Add labels and title
plt.xlabel("Title of Course Studied")
plt.ylabel("Count")
plt.title("Top 20 Titles of Courses Studied by Gender (Ranked)")

# Show the plot
plt.legend(title="Gender", loc='upper right')  
plt.show()

# %%
# Get the top 20 most common titles of courses studied
top_20_titles = df['Title of course studied'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 titles
filtered_df = df[df['Title of course studied'].isin(top_20_titles)]

# Create a pivot table to count the number of each gender within each title
pivot_df = filtered_df.pivot_table(index='Title of course studied', columns='What is your gender', aggfunc='size', fill_value=0)

# Rank the titles by total count in descending order
ranked_titles = pivot_df.sum(axis=1).sort_values(ascending=False).index
pivot_df = pivot_df.loc[ranked_titles]

# Set the style for the plot
sns.set(style="whitegrid")

# Create a horizontal stacked bar chart
plt.figure(figsize=(12, 8))
ax = pivot_df.plot(kind="barh", stacked=True, colormap="viridis")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Title of Course Studied")
plt.title("Top 20 Titles of Courses Studied by Gender (Ranked)")

# Show the plot
plt.legend(title="Gender", loc='lower right')  
plt.show()

# %%
# Get the top 20 most common schools
top_20_schools = df['Polytechnic/University attended'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 schools
filtered_df = df[df['Polytechnic/University attended'].isin(top_20_schools)]

# Get the schools with counts in descending order
school_counts = filtered_df['Polytechnic/University attended'].value_counts().reindex(top_20_schools)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 schools with schools ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Polytechnic/University attended", palette="viridis", order=school_counts.index)

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Polytechnic/University Attended")
plt.title("Top 20 Polytechnic/University Attended (Ranked)")

# Show the plot
plt.show()

# %%
# Get the top 20 most common job levels for the first employment after graduation
top_20_job_levels = df['Thinking about your first employment after graduation, what was your job level?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 job levels
filtered_df = df[df['Thinking about your first employment after graduation, what was your job level?'].isin(top_20_job_levels)]

# Create a pivot table to count the number of each gender within each job level
pivot_df = filtered_df.pivot_table(index='Thinking about your first employment after graduation, what was your job level?', columns='What is your gender', aggfunc='size', fill_value=0)

# Rank the job levels by total count in descending order
ranked_job_levels = pivot_df.sum(axis=1).sort_values(ascending=False).index
pivot_df = pivot_df.loc[ranked_job_levels]

# Set the style for the plot
sns.set(style="whitegrid")

# Create a horizontal stacked bar chart
plt.figure(figsize=(12, 8))
ax = pivot_df.plot(kind="barh", stacked=True, colormap="viridis")

# Add labels and title
plt.ylabel("Job Level for First Employment After Graduation")
plt.xlabel("Count")
plt.title("Job Levels for First Employment After Graduation by Gender (Ranked)")

# Show the plot
plt.legend(title="Gender", loc='lower right')  
plt.show()

# %%
# Get the top 20 most common job levels for the first employment after graduation
top_20_job_levels = df['Thinking about your first employment after graduation, what was your job level?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 job levels
filtered_df = df[df['Thinking about your first employment after graduation, what was your job level?'].isin(top_20_job_levels)]

# Get the job levels with counts in descending order
job_level_counts = filtered_df['Thinking about your first employment after graduation, what was your job level?'].value_counts().reindex(top_20_job_levels)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 job levels with levels ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Thinking about your first employment after graduation, what was your job level?",
                   palette="viridis", order=job_level_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Job Level")
plt.title("Job Levels for First Employment After Graduation (Ranked) with Gender Legend")

# Show the plot
plt.legend(title="Gender") 
plt.show()

# %%
# Get the top 20 most common job levels for the first employment after graduation
top_20_job_levels = df['Thinking about your first employment after graduation, what was your job level?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 job levels
filtered_df = df[df['Thinking about your first employment after graduation, what was your job level?'].isin(top_20_job_levels)]

# Get the job levels with counts in descending order
job_level_counts = filtered_df['Thinking about your first employment after graduation, what was your job level?'].value_counts().reindex(top_20_job_levels)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 job levels with levels ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Thinking about your first employment after graduation, what was your job level?",
                   palette="viridis", order=job_level_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Job Level")
plt.title("Job Levels for First Employment After Graduation (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common job roles
top_20_job_roles = df['What is/was your job role?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 job roles
filtered_df = df[df['What is/was your job role?'].isin(top_20_job_roles)]

# Get the job roles with counts in descending order
job_role_counts = filtered_df['What is/was your job role?'].value_counts().reindex(top_20_job_roles)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 job roles with roles ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="What is/was your job role?",
                   palette="viridis", order=job_role_counts.index, hue="What is your gender") 

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Job Role")
plt.title("Top 20 Job Roles (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common sectors/industries
top_20_sectors = df['What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 sectors/industries
filtered_df = df[df['What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1'].isin(top_20_sectors)]

# Get the sectors/industries with counts in descending order
sector_counts = filtered_df['What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1'].value_counts().reindex(top_20_sectors)

# Set a custom color palette for better colors
custom_palette = sns.color_palette("Set2")

# Create a countplot for the top 20 sectors/industries with sectors ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1",
                   palette=custom_palette, order=sector_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Company Sector/Industry")
plt.title("Top 20 Company Sectors/Industries (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common income levels
top_20_income_levels = df['Still thinking about your first employment, what is/was your monthly income level?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 income levels
filtered_df = df[df['Still thinking about your first employment, what is/was your monthly income level?'].isin(top_20_income_levels)]

# Get the income levels with counts in descending order
income_counts = filtered_df['Still thinking about your first employment, what is/was your monthly income level?'].value_counts().reindex(top_20_income_levels)

# Set a custom color palette for better colors
custom_palette = sns.color_palette("tab20")

# Create a countplot for the top 20 income levels with income levels ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Still thinking about your first employment, what is/was your monthly income level?",
                   palette=custom_palette, order=income_counts.index, hue="What is your gender") 

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Monthly Income Level")
plt.title("Monthly Income Levels (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common responses
top_20_responses = df['Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 responses
filtered_df = df[df['Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?'].isin(top_20_responses)]

# Get the responses with counts in descending order
response_counts = filtered_df['Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?'].value_counts().reindex(top_20_responses)

# Set a custom color palette for better colors
custom_palette = sns.color_palette("Set3")

# Create a countplot for the top 20 responses with responses ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?",
                   palette=custom_palette, order=response_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Qualification Required for First Job")
plt.title("Qualifications Required for First Job (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common responses
top_20_responses = df['Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 responses
filtered_df = df[df['Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?'].isin(top_20_responses)]

# Get the responses with counts in descending order
response_counts = filtered_df['Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?'].value_counts().reindex(top_20_responses)

# Set a custom color palette for better colors
custom_palette = sns.color_palette("Set3")

# Create a countplot for the top 20 responses with responses ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?",
                   palette=custom_palette, order=response_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Qualification Required for First Job")
plt.title("Top 20 Qualifications Required for First Job (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Set custom color palette with blue and red
custom_palette = sns.color_palette(["blue", "red"])

# Create a countplot for the "Did you need your higher education qualification to get your first job?" column
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x="Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?",
                   palette=custom_palette, hue="What is your gender")

# Rotate x-axis labels for better visibility
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# Add labels and title
plt.xlabel("Higher Education Qualification Needed for First Job")
plt.ylabel("Count")
plt.title("Higher Education Qualification Requirement for First Job with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common job levels for current employment
top_20_current_job_levels = df['Thinking about your current employment, what is your job level?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 job levels
filtered_df = df[df['Thinking about your current employment, what is your job level?'].isin(top_20_current_job_levels)]

# Get the job levels with counts in descending order
current_job_level_counts = filtered_df['Thinking about your current employment, what is your job level?'].value_counts().reindex(top_20_current_job_levels)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 job levels for current employment with levels ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="Thinking about your current employment, what is your job level?",
                   palette="viridis", order=current_job_level_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Job Level")
plt.title("Current Employment (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common job roles for current employment
top_20_current_job_roles = df['What is your job role?'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 job roles
filtered_df = df[df['What is your job role?'].isin(top_20_current_job_roles)]

# Get the job roles with counts in descending order
current_job_role_counts = filtered_df['What is your job role?'].value_counts().reindex(top_20_current_job_roles)

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 job roles for current employment with roles ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="What is your job role?",
                   palette="viridis", order=current_job_role_counts.index, hue="What is your gender")  

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Job Role")
plt.title("Top 20 Job Roles for Current Employment (Ranked) with Gender Legend")

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Get the top 20 most common sectors/industries for current employment
top_20_sectors = df['What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1'].value_counts().head(20).index

# Filter the DataFrame for only these top 20 sectors/industries
filtered_df = df[df['What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1'].isin(top_20_sectors)]

# Get the sectors/industries with counts in descending order
sector_counts = filtered_df['What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1'].value_counts().reindex(top_20_sectors)

# Set the new color palette
colors = sns.color_palette("husl", len(top_20_sectors))

# Create a countplot for the top 20 sectors/industries for current employment with sectors ordered by count
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=filtered_df, y="What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication).1",
                   palette=colors, order=sector_counts.index)

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Sector/Industry")
plt.title("Top 20 Sectors/Industries for Current Employment (Ranked)")

# Show the plot
plt.show()

# %%
# Get the counts of each income level
income_counts = df['What is your current monthly income level?'].value_counts()

# Sort the income levels by count in descending order
sorted_income_levels = income_counts.index

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the current monthly income levels with levels ordered by count
plt.figure(figsize=(12, 8))
ax = sns.countplot(data=df, y="What is your current monthly income level?", palette="viridis", order=sorted_income_levels)

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Income Level")
plt.title("Current Monthly Income Levels (Ranked)")

# Show the plot
plt.show()

# %%
# Set custom color palette with blue and red
custom_palette = sns.color_palette(["blue", "red"])

# Create a countplot for the "Did you need your higher education qualification to get this job (the actual qualification, not the subject of study)?" column
plt.figure(figsize=(10, 8))
ax = sns.countplot(data=df, y="Did you need your higher education qualification to get this job (the actual qualification, not the subject of study)?",
                   palette=custom_palette, hue="What is your gender")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Higher Education Qualification Needed for Job")
plt.title("Higher Education Qualification Requirement for Job with Gender Legend")

# Reorder the y-axis labels by count
order = df['Did you need your higher education qualification to get this job (the actual qualification, not the subject of study)?'].value_counts().index
ax.set_yticklabels(order)

# Move the legend outside the chart
plt.legend(title="Gender", bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a cross-tabulation table for "What is your gender" and "What currency are you currently paid in?"
cross_tab = pd.crosstab(index=df["What is your gender"], columns=df["What currency are you currently paid in?"])

# Create a countplot based on the cross-tabulation table
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="What currency are you currently paid in?", hue="What is your gender", palette="Set2")

# Add labels and title
plt.xlabel("Currency for Payment")
plt.ylabel("Count")
plt.title("Gender-Based Differences in Currency for Payment")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a box plot for the "Approximately how many hours a day do you currently work?" column
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, y="Approximately how many hours a day do you currently work?", palette="viridis")

# Add labels and title
plt.xlabel("Hours Worked per Day")
plt.ylabel("Approximately how many hours a day do you currently work")
plt.title("Box Plot of Daily Working Hours")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the "How do you find out about your job(s)?" column
plt.figure(figsize=(10, 6))
sns.countplot(data=df, y="How do you find out about your job(s)?", palette="viridis")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("How do you find out about your job(s)?")
plt.title("How Graduates Find Job Opportunities")

# Show the plot
plt.show()

# %%
# Get the counts of each method for finding out about jobs and rank them in descending order
method_counts = df['How do you find out about your job(s)?'].value_counts().sort_values(ascending=False)

# Get the top 20 methods
top_20_methods = method_counts.head(20).index

# Filter the DataFrame for the top 20 methods
filtered_df = df[df['How do you find out about your job(s)?'].isin(top_20_methods)]

# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the top 20 methods of finding out about jobs with methods ordered by count
plt.figure(figsize=(12, 8))
ax = sns.countplot(data=filtered_df, y="How do you find out about your job(s)?", palette="viridis",
                   order=top_20_methods)

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Method of Finding Jobs")
plt.title("Top 20 Methods of Finding Out About Jobs (Ranked)")

# Show the plot
plt.show()

# %%
# Set the style for the plot
sns.set(style="whitegrid")

# Create a countplot for the "Thinking about your current employment, did you work for your employer before or during your higher education study?" column
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x=df["Thinking about your current employment, did you work for your employer before or during your  higher education study?"], palette="viridis")

# Rotate x-axis labels for better visibility
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

# Add labels and title
plt.xlabel("Work Experience Before/During Higher Education")
plt.ylabel("Count")
plt.title("Employment History Before/During Higher Education")

# Show the plot
plt.show()

# %%
# Get the counts of each transport method and rank them in descending order
transport_counts = df["Which form of transport do you use the most?"].value_counts().sort_values(ascending=False)

# Create a bar chart
plt.figure(figsize=(10, 8))
sns.barplot(y=transport_counts.index, x=transport_counts.values, palette="viridis")

# Add labels and title
plt.xlabel("Count")
plt.ylabel("Transport Method")
plt.title("Most Used Transport Methods (Ranked)")

# Show the plot
plt.show()

# %%
# Get the counts of responses in the column
rent_or_buy_counts = df["Were you able to rent an apartment or buy a car from the salary you got from your first job?"].value_counts()

# Create a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=rent_or_buy_counts.index, y=rent_or_buy_counts.values, palette="Set2")

# Add labels and title
plt.xlabel("Response")
plt.ylabel("Count")
plt.title("Ability to Rent an Apartment or Buy a Car from First Job Salary")

# Show the plot
plt.show()
