# %%
import pandas as pd

# %%
df = pd.read_csv("/content/modelcraftdata.csv")

# %%
df.head()
# Out:
#             Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05:23                Male                2013
# 1  2/15/2018 12:11:32                Male                2014
# 2  2/15/2018 13:47:10              Female                2013
# 3  2/16/2018 13:01:34                Male                2017
# 4  2/16/2018 13:18:03              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
# ...

# %%
df.shape
# Out:
# (5219, 36)

# %%
df.isna().any()
# Out:
# Timestamp                                                                                                                       False
# What is your gender                                                                                                             False
# Year of graduation                                                                                                              False
# Title of course studied                                                                                                         False
# Polytechnic/University attended                                                                                                 False
# What is your highest level of education?                                                                                        False
# What best describes your current status?                                                                                        False
# ...

# %%
check = df.fillna("Not applicable")

# %%
check.isna().any()
# Out:
# Timestamp                                                                                                                       False
# What is your gender                                                                                                             False
# Year of graduation                                                                                                              False
# Title of course studied                                                                                                         False
# Polytechnic/University attended                                                                                                 False
# What is your highest level of education?                                                                                        False
# What best describes your current status?                                                                                        False
# ...

# %%
del df["Timestamp"]

# %%
for col in check.columns:
  print(check[col].value_counts())
  print("===============================================================================================")
# Out:
# 4/3/2018 13:48:12     2
# 3/7/2018 11:01:28     2
# 3/25/2018 18:20:33    2
# 3/6/2018 12:51:51     2
# 3/2/2018 17:03:54     2
#                      ..
# 3/6/2018 13:02:33     1
# 3/6/2018 13:02:22     1
# 3/6/2018 13:02:18     1
# 3/6/2018 13:01:27     1
# 5/15/2018 23:39:09    1
# Name: Timestamp, Length: 5205, dtype: int64
# ...
# Male                 2624
# Female               2592
# Prefer not to say       3
# Name: What is your gender, dtype: int64
# ...
# 2015    1327
# 2017    1259
# 2016    1214
# 2014     824
# 2013     595
# Name: Year of graduation, dtype: int64
# ...
# Computer Science                                        459
# Accountancy                                             373
# Economics                                               321
# Electrical & Electronic Engineering                     214
# Mass Communication (Communication and Language Arts)    204
#                                                        ...
# ...

# %%
ndf = df[['What is your gender','Year of graduation','Title of course studied','Polytechnic/University attended','What is your highest level of education?',"What best describes your current status?","How many jobs have you had since graduation including your current one?",'Have you completed your NYSC?',"Did you get your first full time job through your NYSC placement?",'Thinking about your first employment after graduation, what was your job level?']]

# %%
ndf.isna().sum()
# Out:
# What is your gender                                                                   0
# Year of graduation                                                                    0
# Title of course studied                                                               0
# Polytechnic/University attended                                                       0
# What is your highest level of education?                                              0
# What best describes your current status?                                              0
# How many jobs have you had since graduation including your current one?               0
# Have you completed your NYSC?                                                         1
# Did you get your first full time job through your NYSC placement?                     1
# Thinking about your first employment after graduation, what was your job level?    3563
# dtype: int64

# %%
ndf = ndf.dropna()

# %%
ndf.isna().sum()
# Out:
# What is your gender                                                                0
# Year of graduation                                                                 0
# Title of course studied                                                            0
# Polytechnic/University attended                                                    0
# What is your highest level of education?                                           0
# What best describes your current status?                                           0
# How many jobs have you had since graduation including your current one?            0
# Have you completed your NYSC?                                                      0
# Did you get your first full time job through your NYSC placement?                  0
# Thinking about your first employment after graduation, what was your job level?    0
# dtype: int64

# %%
ndf.shape
# Out:
# (1655, 10)

# %%
for col in ndf.columns:
  print(df[col].value_counts())
  print("===============================================================================================")
# Out:
# Male                 2624
# Female               2592
# Prefer not to say       3
# Name: What is your gender, dtype: int64
# ...
# 2015    1327
# 2017    1259
# 2016    1214
# 2014     824
# 2013     595
# Name: Year of graduation, dtype: int64
# ...
# Computer Science                                        459
# Accountancy                                             373
# Economics                                               321
# Electrical & Electronic Engineering                     214
# Mass Communication (Communication and Language Arts)    204
#                                                        ...
# Music                                                     1
# Department of Pharmacology and Toxicology                 1
# Child Dental Health                                       1
# Archeology and Tourism                                    1
# Igbo Linguistics                                          1
# Name: Title of course studied, Length: 127, dtype: int64
# ...

# %%
#replace values in columns with respodents less than 100
columns = ['Title of course studied','Polytechnic/University attended']
for col in columns:
  series = ndf[col].value_counts()
  less_than_100 = [] #
  #
  for key in series.keys():
    if series[key] < 10:
      less_than_100.append(key)

  #drop institution with less than 10 respondents to balance data
  for val in less_than_100:
    ndf.loc[ndf[col] == val, col] = 'Others'

# %%
for col in ndf.columns:
  print(ndf[col].value_counts())
  print("===============================================================================================")
# Out:
# Male                 871
# Female               783
# Prefer not to say      1
# Name: What is your gender, dtype: int64
# ...
# 2015    457
# 2014    376
# 2013    311
# 2016    290
# 2017    221
# Name: Year of graduation, dtype: int64
# ...
# Others                                                  283
# Computer Science                                        159
# Economics                                               110
# Accountancy                                             108
# Mass Communication (Communication and Language Arts)     82
# Electrical & Electronic Engineering                      64
# Business Administration                                  62
# Biochemistry                                             57
# Mechanical Engineering                                   51
# Law                                                      41
# Microbiology                                             39
# Political Science                                        38
# ...

# %%
ndf.columns
# Out:
# Index(['What is your gender', 'Year of graduation', 'Title of course studied',
#        'Polytechnic/University attended',
#        'What is your highest level of education?',
#        'What best describes your current status?',
#        'How many jobs have you had since graduation including your current one?',
#        'Have you completed your NYSC?',
#        'Did you get your first full time job through your NYSC placement?',
#        'Thinking about your first employment after graduation, what was your job level?'],
#       dtype='object')

# %%
ndf.head()
# Out:
#   What is your gender  Year of graduation  \
# 1                Male                2014
# 2              Female                2013
# 4              Female                2013
# 5                Male                2015
# 6                Male                2013
#
#                Title of course studied     Polytechnic/University attended  \
# 1                           Psychology  Obafemi Awolowo University,Ile-Ife
# 2                            Economics                              Others
# 4                           Statistics              Ekiti State University
# 5  Electrical & Electronic Engineering                 University of Benin
# 6                            Economics               Bowen University, Iwo
#
#   What is your highest level of education?  \
# 1                        Bachelor's degree
# 2                        Bachelor's degree
# 4                        Bachelor's degree
# 5                        Bachelor's degree
# ...

# %%
ndf['What is your gender'].replace(['Male', 'Female','Prefer not to say'],
                        [0, 1, 2], inplace=True)

# %%
ndf['Year of graduation'].replace([2013, 2014,2015,2016,2017],
                        [0, 1, 2, 3, 4], inplace=True)

# %%
list(ndf['Title of course studied'].value_counts().keys())
# Out:
# ['Others',
#  'Computer Science',
#  'Economics',
#  'Accountancy',
#  'Mass Communication (Communication and Language Arts)',
#  'Electrical & Electronic Engineering',
#  'Business Administration',
#  'Biochemistry',
#  'Mechanical Engineering',
#  'Law',
#  'Microbiology',
#  'Political Science',
#  'History and International Studies',
#  'English and Literary Studies',
#  'Computer Engineering',
#  'Civil Engineering',
#  'Architecture',
#  'Chemical Engineering',
#  'Banking and Finance',
#  'Geography',
#  'Industrial Relations and Personnel Management',
#  'Physics and Astronomy',
#  'Medicine',
#  'Geology',
#  'Psychology',
#  'Estate Management',
#  'Statistics',
#  'Education & Economics',
#  'Mathematics',
#  'Sociology/Anthropology',
#  'Petroleum and Gas Engineering',
#  'Agricultural Economics',
#  'Philosophy',
#  'Food Science and Technology',
#  'Linguistics and Nigerian Languages',
#  'Pure and Industrial Chemistry',
#  'Business Management',
# ...

# %%
list(ndf['Title of course studied'].value_counts().keys())
# Out:
# ['Others',
#  'Computer Science',
#  'Economics',
#  'Accountancy',
#  'Mass Communication (Communication and Language Arts)',
#  'Electrical & Electronic Engineering',
#  'Business Administration',
#  'Biochemistry',
#  'Mechanical Engineering',
#  'Law',
#  'Microbiology',
#  'Political Science',
#  'History and International Studies',
#  'English and Literary Studies',
#  'Computer Engineering',
#  'Civil Engineering',
#  'Architecture',
#  'Chemical Engineering',
#  'Banking and Finance',
#  'Geography',
#  'Industrial Relations and Personnel Management',
#  'Physics and Astronomy',
#  'Medicine',
#  'Geology',
#  'Psychology',
#  'Estate Management',
#  'Statistics',
#  'Education & Economics',
#  'Mathematics',
#  'Sociology/Anthropology',
#  'Petroleum and Gas Engineering',
#  'Agricultural Economics',
#  'Philosophy',
#  'Food Science and Technology',
#  'Linguistics and Nigerian Languages',
#  'Pure and Industrial Chemistry',
#  'Business Management',
# ...

# %%
ndf['Title of course studied'].replace(list(ndf['Title of course studied'].value_counts().keys()),
                        range(0,len(list(ndf['Title of course studied'].value_counts().keys()))), inplace=True)

# %%
list(ndf['Polytechnic/University attended'].value_counts().keys())
# Out:
# ['Others',
#  'Covenant University Ota',
#  'University of Lagos',
#  'Obafemi Awolowo University,Ile-Ife',
#  'University of Ibadan',
#  'Babcock University,Ilishan-Remo',
#  'University of Benin',
#  'University of Ilorin',
#  'Others (For foreign trained students)',
#  'Lagos State University Ojo, Lagos.',
#  'University of Nigeria, Nsukka',
#  'University of Agriculture, Abeokuta.',
#  'Bowen University, Iwo',
#  'Ladoke Akintola University of Technology, Ogbomoso',
#  'University of Port-Harcourt',
#  'Ekiti State University',
#  'Olabisi Onabanjo University Ago-Iwoye',
#  'Federal University of Technology, Akure',
#  'Nnamdi Azikiwe University, Awka',
#  'Federal University of Technology, Owerri',
#  'Ahmadu Bello University, Zaria',
#  'Federal University of Technology, Minna.',
#  'Lagos State Polytechnic, Ikorodu, Ikeja, Lagos, Lagos State.',
#  'Adekunle Ajasin University, Akungba.',
#  'Imo State University, Owerri',
#  "Redeemer's University, Mowe",
# ...

# %%
ndf['Polytechnic/University attended'].replace(list(ndf['Polytechnic/University attended'].value_counts().keys()),
                        range(0,len(list(ndf['Polytechnic/University attended'].value_counts().keys()))), inplace=True)

# %%
ndf['What is your highest level of education?'].replace(['Ordinary National Diploma (OND)', 'Higher National Diploma (HND)',"Bachelor's degree",'MBA degree',"Master's degree",'PhDs/Doctorate Degree'],
                        [0, 1, 2, 3, 4,5], inplace=True)

# %%
ndf['Have you completed your NYSC?'].replace(['Yes', 'No','Ongoing'],
                        [0, 1, 2], inplace=True)

# %%
ndf['Did you get your first full time job through your NYSC placement?'].replace(['Yes', 'No','I have not completed my NYSC'],
                        [0, 1, 2], inplace=True)

# %%
ndf['What best describes your current status?'].replace(list(ndf['What best describes your current status?'].value_counts().keys()),
                        range(0,len(list(ndf['What best describes your current status?'].value_counts().keys()))), inplace=True)

# %%
# ndf['Thinking about your current employment, what is your job level?'].replace(['Entry level', 'Clerical and administrative','Experience','Experience/Professional','Managerial','Executive Director'],
#                         [0, 1, 2, 3, 4, 5], inplace=True)

# %%
ndf['Thinking about your first employment after graduation, what was your job level?'].replace(['Entry level', 'Clerical and administrative','Experience/Professional','Managerial','Executive Director'],
                        [0, 1, 2, 3, 4], inplace=True)

# %%
list(ndf['How many jobs have you had since graduation including your current one?'].value_counts().keys())
# Out:
# [2, 3, 4, 5, 10, 6, 7, 8]

# %%
ndf.head()
# Out:
#    What is your gender  Year of graduation  Title of course studied  \
# 1                    0                   1                       24
# 2                    1                   0                        2
# 4                    1                   0                       26
# 5                    0                   2                        5
# 6                    0                   0                        2
#
#    Polytechnic/University attended  What is your highest level of education?  \
# 1                                3                                         2
# 2                                0                                         2
# 4                               15                                         2
# 5                                6                                         2
# 6                               12                                         1
#
#    What best describes your current status?  \
# 1                                         0
# ...

# %%
abs(ndf.corr())
# Out:
#                                                     What is your gender  \
# What is your gender                                            1.000000
# Year of graduation                                             0.090038
# Title of course studied                                        0.009267
# Polytechnic/University attended                                0.031868
# What is your highest level of education?                       0.001306
# What best describes your current status?                       0.041759
# How many jobs have you had since graduation inc...             0.041734
# Have you completed your NYSC?                                  0.083554
# Did you get your first full time job through yo...             0.014309
# Thinking about your first employment after grad...             0.031400
#
#                                                     Year of graduation  \
# What is your gender                                           0.090038
# ...

# %%
X = ndf[['What is your gender','Year of graduation','Title of course studied','Polytechnic/University attended','What is your highest level of education?',"What best describes your current status?",'Have you completed your NYSC?']]
y = ndf['Thinking about your first employment after graduation, what was your job level?']

# %%
from sklearn.feature_selection import SelectKBest, chi2
x = SelectKBest(chi2, k=7).fit_transform(X, y)
x.shape
# Out:
# (1655, 7)

# %%
from sklearn import feature_selection
from sklearn.feature_selection import SelectKBest, f_classif,chi2
selector = SelectKBest(chi2, k = 7)
fit = selector.fit_transform(X, y)
#New dataframe with the selected features for later use in the classifier. fit() method works too, if you want only the feature names and their corresponding scores
X_new = selector.fit_transform(X, y)
names = X.columns.values[selector.get_support()]
scores = selector.scores_[selector.get_support()]
names_scores = list(zip(names, scores))
ns_df = pd.DataFrame(data = names_scores, columns=['Feat_names', 'F_Scores'])
#Sort the dataframe for better visualization
ns_df_sorted = ns_df.sort_values(['F_Scores', 'Feat_names'], ascending = [False, True])
print(ns_df_sorted)
# Out:
#                                  Feat_names    F_Scores
# 2                   Title of course studied  118.593350
# 6             Have you completed your NYSC?   28.713925
# 3           Polytechnic/University attended   24.417434
# 0                       What is your gender   14.597875
# 1                        Year of graduation    5.845577
# 5  What best describes your current status?    5.691148
# 4  What is your highest level of education?    2.027385

# %%
ns_df_sorted['Feat_names'].values
# Out:
# array(['Title of course studied', 'Have you completed your NYSC?',
#        'Polytechnic/University attended', 'What is your gender',
#        'Year of graduation', 'What best describes your current status?',
#        'What is your highest level of education?'], dtype=object)

# %%
import pandas as pd
from matplotlib import pyplot as plt



feature = list(ns_df_sorted['Feat_names'].values)
score = list(ns_df_sorted['F_Scores'].values)

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))

# Horizontal Bar Plot
ax.barh(feature, score)

# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')

# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)


# Show top values
ax.invert_yaxis()

# Add annotation to bars
for i in ax.patches:
	plt.text(i.get_width()+0.2, i.get_y()+0.5,
			str(round((i.get_width()), 2)),
			fontsize = 10, fontweight ='bold',
			color ='grey')

# Add Plot Title
ax.set_title('Feature Importance',
			loc ='left', )

# Add Text watermark
fig.text(0.9, 0.15, 'ModelCraft', fontsize = 12,
		color ='grey', ha ='right', va ='bottom',
		alpha = 0.7)

# Show Plot
plt.show()

# %%
X = ndf[['What is your gender','Title of course studied','Polytechnic/University attended','Have you completed your NYSC?']]
#X = ndf[['Year of graduation','Title of course studied','Polytechnic/University attended',"What best describes your current status?","How many jobs have you had since graduation including your current one?"]]
y = ndf['Thinking about your first employment after graduation, what was your job level?']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.20, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=6, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, random_state=42)

# %%
pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
import numpy as np

print(classification_report(np.round(y_test), np.round(pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.83       235
#            1       1.00      0.02      0.04        45
#            2       0.33      0.02      0.04        42
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.71       331
#    macro avg       0.41      0.21      0.18       331
# weighted avg       0.69      0.71      0.60       331
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# save the model to disk
import joblib

joblib.dump(clf, "model.sav")
# Out:
# ['model.sav']

# %%
c = joblib.load("model.sav")

# %%
import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 1.2.2.

# %%
c.predict([[1,2,3,4]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, pred)
# Out:
# 0.7129909365558912

# %%
#svm
from sklearn.svm import SVC
sclf = SVC()
sclf.fit(X_train, y_train)
spred = sclf.predict(X_test)
accuracy_score(y_test, spred)
# Out:
# 0.7099697885196374

# %%
print(classification_report(np.round(y_test), np.round(spred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       235
#            1       0.00      0.00      0.00        45
#            2       0.00      0.00      0.00        42
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.71       331
#    macro avg       0.14      0.20      0.17       331
# weighted avg       0.50      0.71      0.59       331
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth=6,random_state=42)
clf.fit(X_train, y_train)
spred = clf.predict(X_test)
accuracy_score(y_test, spred)
# Out:
# 0.6827794561933535

# %%
print(classification_report(np.round(y_test), np.round(spred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81       235
#            1       0.25      0.13      0.17        45
#            2       0.33      0.02      0.04        42
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.68       331
#    macro avg       0.26      0.22      0.21       331
# weighted avg       0.59      0.68      0.61       331
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=4, random_state=42).fit(X_train, y_train)
spred = clf.predict(X_test)
accuracy_score(y_test, spred)
# Out:
# 0.7129909365558912

# %%
print(classification_report(np.round(y_test), np.round(spred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       235
#            1       0.00      0.00      0.00        45
#            2       1.00      0.02      0.05        42
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.71       331
#    macro avg       0.34      0.20      0.18       331
# weighted avg       0.63      0.71      0.60       331
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=4, random_state=42)
clf.fit(X_train, y_train)
spred = clf.predict(X_test)
accuracy_score(y_test, spred)
# Out:
# 0.7099697885196374

# %%
print(classification_report(np.round(y_test), np.round(spred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      1.00      0.83       235
#            1       0.00      0.00      0.00        45
#            2       0.00      0.00      0.00        42
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         1
#
#     accuracy                           0.71       331
#    macro avg       0.14      0.20      0.17       331
# weighted avg       0.50      0.71      0.59       331
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
